# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nwfsc-math-bio/pycax/blob/main/notebooks/usage_guide.ipynb)

# %% [markdown]
# # pycax Example Usage
# pycax parent repo: [github.com/nwfsc-math-bio/pycax](https://github.com/nwfsc-math-bio/pycax). This Notebook contains examples of modules inside pycax package. pycax is the Python client for the CAX API.

# %% [markdown]
# ## Installing pycax

# %%
try:
  import pycax
except:
  # %pip install pycax-client
  # use this if your want to install the dev version
  # !pip install -q git+https://github.com/nwfsc-math-bio/pycax.git

# %% [markdown]
# ## datasets module
#
# List the available tables

# %%
import pandas as pd
import pycax
res = pycax.datasets.getdf()

# %%
res[['name', 'id']].head()
# Out:
#                            name                                    id
# 0              SuperPopulations  009A08FE-6479-44FC-9B6F-01C55E2C8BA3
# 1                   XPortCA_PNI  0474CE96-789B-4E16-8FD5-05C431E5034A
# 2                   EscData4GIS  0603946B-84FF-450D-8F3E-C2513517126D
# 3  XPortCA_PresmoltAbundance_01  086448AE-4F1F-4FE1-B794-6CC4FB0C451F
# 4                     Reference  1FB86FDA-2DC0-4FCD-9B7F-E37C0C57114F

# %% [markdown]
# ## hli module
#
# Get the HLI (high level indicator) table. By default the xport table (same one used in the CAX web app) is returned. The xport table is a subset of the full table. The fargs argument is used to subset the returned information based on column names. Here column popid with value equal 7 is returned. The number of rows returned in 1000 by default and can be changed with `qargs={'limit': 10000}`, for example.

# %%
res = pycax.hli.getdf('NOSA', fargs={'popid': 7})
res.head()
# Out:
#   nosaijupperlimit   tsaej age8propupperlimit         metriclocation
# 0                    134.0                                            \
# 1                   1112.0
# 2                    987.0
# 3            694.0                             npt-cdms.nezperce.org
# 4                     72.0
#
#                                          popfitnotes         species
# 0                                                     Chinook salmon  \
# 1                                                     Chinook salmon
# 2                                                     Chinook salmon
# 3  25; Percent population coverage estimated from...  Chinook salmon
# 4                                                     Chinook salmon
#
#      datasetversion                    cbfwapopname  nmfs_popid
# 0  2023/04/22 01:32  Catherine Creek Spring Chinook          62  \
# 1  2023/04/22 01:32  Catherine Creek Spring Chinook          62
# 2  2023/04/22 01:32  Catherine Creek Spring Chinook          62
# 3  2023/04/22 01:32                                          62
# 4  2023/04/22 01:32  Catherine Creek Spring Chinook          62
#
#   age9proplowerlimit  ... age11plusprop age11plusproplowerlimit agency
# 0                     ...                                         ODFW  \
# 1                     ...                                         ODFW
# 2                     ...                                         ODFW
# 3                     ...                                          NPT
# 4                     ...                                         ODFW
#
#                     commonpopname
# 0  Catherine Creek spring Chinook  \
# 1  Catherine Creek spring Chinook
# 2  Catherine Creek spring Chinook
# 3                           GRCAT
# 4  Catherine Creek spring Chinook
#
#                                               esudps age6prop tsaejupperlimit
# 0  Salmon Chinook (Snake River spring/summer-run ...      0.0                  \
# 1  Salmon Chinook (Snake River spring/summer-run ...      0.0
# 2  Salmon Chinook (Snake River spring/summer-run ...      0.0
# 3  Salmon Chinook (Snake River spring/summer-run ...
# 4  Salmon Chinook (Snake River spring/summer-run ...      0.0
#
#   age6proplowerlimit hli_id                                         esapopname
# 0                         5  Salmon, Chinook (Snake River spring/summer-run...
# 1                         5  Salmon, Chinook (Snake River spring/summer-run...
# 2                         5  Salmon, Chinook (Snake River spring/summer-run...
# 3                         3  Salmon, Chinook (Snake River spring/summer-run...
# 4                         5  Salmon, Chinook (Snake River spring/summer-run...
#
# [5 rows x 117 columns]

# %% [markdown]
# ## tables module
#
# Get a table using table name.

# %%
res = pycax.tables.getdf('EscData', qargs= {'limit': 3})
res
# Out:
#    ascode countpermile repeatspawners  asnid  agencyid countcidisttype
# 0      98                                 98        15                  \
# 1      98          0.0                    98        10
# 2      98                                 98        15
#
#   countciuplim compilerrecordid                    begindate
# 0                                 November, 01 1979 00:00:00  \
# 1                                September, 03 2002 00:00:00
# 2                                    March, 01 1973 00:00:00
#
#                                      id  ... calcmethid  countvalue trendid
# 0  00000A70-075A-4AE1-857D-42BC1048939C  ...        314      1024.0   54227  \
# 1  0000219F-A662-4A16-8F46-ED171C56990A  ...        304         0.0   44227
# 2  0000578E-E906-41CA-A778-7EC7A8C06DDA  ...         98               53571
#
#   timessurveyed asmethod assource  countcilowlim  milessurveyed countcilevel
# 0                     98                                                      \
# 1             1       98                               2.982007
# 2                     98
#
#    nullflag
# 0        No
# 1        No
# 2       Yes
#
# [3 rows x 29 columns]
